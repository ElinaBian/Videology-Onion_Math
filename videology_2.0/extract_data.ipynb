# %%
import pymongo
import pandas as pd
import numpy as np

# %%
# read data and sorted by event_time
raw_data = pd.read_csv('/Users/elinabian 1/Desktop/CU-life/intern/洋葱数学/videology_2.0/query_result.csv')
raw_data.columns = ['video_id', 'user_id', 'event_key', 'event_time', 
                    'drag_start', 'drag_end', 'time_stamp', 'answer_correct']
print(raw_data.head(20))
sorted_data = raw_data.sort_values('event_time')
sorted_data.index = pd.RangeIndex(len(sorted_data.index))
print(sorted_data.head(20))   #有特别多相同的event_time是否合理
# Out:
#                                 video_id                   user_id  \
# 0   837bc38c-555e-11e7-9482-93e059bc68e2  56286c93dccbd9b10af89a54
# 1   83923900-555e-11e7-9490-375a9082275e  5770abe0c7643d2923cf62ae
# 2   837bc38c-555e-11e7-9482-93e059bc68e2  5790d053a7971e4e4ba46b5d
# 3   837bc38c-555e-11e7-9482-93e059bc68e2  57934df70ac7f34f79355db9
# 4   83a8e704-555e-11e7-949e-8fcc1a16ded8  57c79735c88b9619c36f28d4
# 5   837bc38c-555e-11e7-9482-93e059bc68e2  57ca2df01c2f4976055cb7b5
# 6   83923900-555e-11e7-9490-375a9082275e  57d56650c2fb539069ff790c
# 7   83a8e704-555e-11e7-949e-8fcc1a16ded8  58005324a16d96961dbdda34
# 8   83a8e704-555e-11e7-949e-8fcc1a16ded8  58005324a16d96961dbdda34
# 9   837bc38c-555e-11e7-9482-93e059bc68e2  5819bca596734acc7d456429
# 10  837bc38c-555e-11e7-9482-93e059bc68e2  58391a931a0ca9f005814118
# 11  837bc38c-555e-11e7-9482-93e059bc68e2  584c059bc8cdd8c50539875c
# 12  83923900-555e-11e7-9490-375a9082275e  586f762b4f5e741588c5a96b
# 13  83bcbb58-555e-11e7-94aa-f3fb638c302d  5895d12dfb94ea4e7cd81258
# 14  83a8e704-555e-11e7-949e-8fcc1a16ded8  5899bdd37089267c4a5b45b9
# 15  83a8e704-555e-11e7-949e-8fcc1a16ded8  5899bdd37089267c4a5b45b9
# 16  83923900-555e-11e7-9490-375a9082275e  58a46832ee0064631a0f76c8
# 17  83a8e704-555e-11e7-949e-8fcc1a16ded8  58a91e927a76ec07ea17bcc4
# 18  83bcbb58-555e-11e7-94aa-f3fb638c302d  58a9502d27ca2342d7294995
# 19  83a8e704-555e-11e7-949e-8fcc1a16ded8  58aadf99a00c1005ea579fd2
#
#          event_key     event_time  drag_start  drag_end  time_stamp  \
# 0       startVideo  1524695832690         NaN       NaN         0.0
# 1   clickVideoExit  1524711238550         NaN       NaN         NaN
# 2      finishVideo  1524740052308         NaN       NaN         NaN
# 3        dragVideo  1524750417438         0.0   14249.0         NaN
# 4      finishVideo  1524689845517         NaN       NaN         NaN
# 5       startVideo  1524748552299         NaN       NaN         NaN
# 6      finishVideo  1524727495173         NaN       NaN         NaN
# 7        dragVideo  1524716784078    153614.0    7029.0         NaN
# 8        dragVideo  1524717067965    282573.0  176899.0         NaN
# 9        dragVideo  1524750037805        57.0      81.0         NaN
# 10      startVideo  1524715419144         NaN       NaN         NaN
# 11     finishVideo  1524750515483         NaN       NaN         NaN
# 12     finishVideo  1524751747318         NaN       NaN         NaN
# 13       dragVideo  1524744917884         0.0       0.0         NaN
# 14       dragVideo  1524756651138     57001.0  104622.0         NaN
# 15       dragVideo  1524756694266    193193.0  195481.0         NaN
# 16  clickVideoExit  1524756483562         NaN       NaN    262220.0
# 17  clickVideoExit  1524737849304         NaN       NaN         NaN
# 18      startVideo  1524720295454         NaN       NaN         0.0
# 19      startVideo  1524755239406         NaN       NaN         NaN
#
#     answer_correct
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 7              NaN
# 8              NaN
# 9              NaN
# 10             NaN
# 11             NaN
# 12             NaN
# 13             NaN
# 14             NaN
# 15             NaN
# 16             NaN
# 17             NaN
# 18             NaN
# 19             NaN
#                                 video_id                   user_id  \
# 0   83bcbb58-555e-11e7-94aa-f3fb638c302d  587b631a62de3357b0b22d33
# 1   83a8e704-555e-11e7-949e-8fcc1a16ded8  5af6b5a6aea83f289269e85b
# 2   83bcbb58-555e-11e7-94aa-f3fb638c302d  594061454d95b66e2537f50e
# 3   83bcbb58-555e-11e7-94aa-f3fb638c302d  5aa7cb7ab9c0b32892e2214f
# 4   837bc38c-555e-11e7-9482-93e059bc68e2  5afe5f4ad2b85a2872d5ef1e
# 5   837bc38c-555e-11e7-9482-93e059bc68e2  5ad13e87511dd128fbf037d6
# 6   83923900-555e-11e7-9490-375a9082275e  57f7038f4548b5a70594d0d8
# 7   837bc38c-555e-11e7-9482-93e059bc68e2  5af5815a3c773f289f110187
# 8   837bc38c-555e-11e7-9482-93e059bc68e2  5b08d2eea813c3280f5b9e5a
# 9   83a8e704-555e-11e7-949e-8fcc1a16ded8  5af6b5a6aea83f289269e85b
# 10  837bc38c-555e-11e7-9482-93e059bc68e2  5ad13e87511dd128fbf037d6
# 11  837bc38c-555e-11e7-9482-93e059bc68e2  5af5815a3c773f289f110187
# 12  83923900-555e-11e7-9490-375a9082275e  5af6b5a6aea83f289269e85b
# 13  837bc38c-555e-11e7-9482-93e059bc68e2  57f7038f4548b5a70594d0d8
# 14  837bc38c-555e-11e7-9482-93e059bc68e2  5af6b5a6aea83f289269e85b
# 15  83923900-555e-11e7-9490-375a9082275e  5af7db315d60bf2890e87934
# 16  837bc38c-555e-11e7-9482-93e059bc68e2  5b08d2eea813c3280f5b9e5a
# 17  837bc38c-555e-11e7-9482-93e059bc68e2  5af6b5a6aea83f289269e85b
# 18  83bcbb58-555e-11e7-94aa-f3fb638c302d  59fdc1753acc1e05e9be13f9
# 19  837bc38c-555e-11e7-9482-93e059bc68e2  5b08d2eea813c3280f5b9e5a
#
#          event_key  event_time  drag_start  drag_end  time_stamp  \
# 0       startVideo  2147483647         NaN       NaN         0.0
# 1       startVideo  2147483647         NaN       NaN         0.0
# 2       startVideo  2147483647         NaN       NaN     76998.0
# 3        dragVideo  2147483647    165501.0  194808.0         NaN
# 4       startVideo  2147483647         NaN       NaN         0.0
# 5       startVideo  2147483647         NaN       NaN         0.0
# 6       startVideo  2147483647         NaN       NaN         0.0
# 7        dragVideo  2147483647         0.0   28727.0         NaN
# 8        dragVideo  2147483647    288001.0  296798.0         NaN
# 9       startVideo  2147483647         NaN       NaN         0.0
# 10     finishVideo  2147483647         NaN       NaN         NaN
# 11  clickVideoExit  2147483647         NaN       NaN     31001.0
# 12     finishVideo  2147483647         NaN       NaN         NaN
# 13     finishVideo  2147483647         NaN       NaN         NaN
# 14      startVideo  2147483647         NaN       NaN         0.0
# 15      startVideo  2147483647         NaN       NaN         0.0
# 16       dragVideo  2147483647     73501.0  135952.0         NaN
# 17     finishVideo  2147483647         NaN       NaN         NaN
# 18      startVideo  2147483647         NaN       NaN         0.0
# 19      startVideo  2147483647         NaN       NaN         0.0
#
#     answer_correct
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 7              NaN
# 8              NaN
# 9              NaN
# 10             NaN
# 11             NaN
# 12             NaN
# 13             NaN
# 14             NaN
# 15             NaN
# 16             NaN
# 17             NaN
# 18             NaN
# 19             NaN

# %%
drag_opr = sorted_data[sorted_data['event_key']=='dragVideo']
start_opr = sorted_data[sorted_data['event_key']=='startVideo']
finish_opr = sorted_data[sorted_data['event_key']=='finishVideo']
exit_opr = sorted_data[sorted_data['event_key']=='clickVideoExit']

for i in drag_opr.index:
    a = drag_opr.loc[i, 'drag_start']/1000
    sorted_data.loc[i, 'drag_start'] = np.ceil(a)
    b = drag_opr.loc[i, 'drag_end']/1000
    sorted_data.loc[i, 'drag_end'] = np.ceil(b)
    if i%10000 == 0:
        print(i)
# Out:
# 20000
# 60000
# 80000
# 90000
# 110000
# 120000
# 140000
# 160000
# 180000
# 210000
# 220000
# 230000
# 250000
# 270000
# 280000
# 340000
# 360000
# 370000

# %%
for i in start_opr.index:
    c = start_opr.loc[i, 'time_stamp']/1000
    sorted_data.loc[i, 'time_stamp'] = np.ceil(c)
    if i%50000==0:
        print(i)
# Out:
# 0
# 100000
# 150000
# 200000
# 300000
# 350000

# %%
for i in exit_opr.index:
    e = exit_opr.loc[i, 'time_stamp']/1000
    sorted_data.loc[i, 'time_stamp'] = np.ceil(e)
    if i%50000==0:
        print(i)
    
print(sorted_data.head(20))
# Out:
# 50000
#                                 video_id                   user_id  \
# 0   83bcbb58-555e-11e7-94aa-f3fb638c302d  587b631a62de3357b0b22d33
# 1   83a8e704-555e-11e7-949e-8fcc1a16ded8  5af6b5a6aea83f289269e85b
# 2   83bcbb58-555e-11e7-94aa-f3fb638c302d  594061454d95b66e2537f50e
# 3   83bcbb58-555e-11e7-94aa-f3fb638c302d  5aa7cb7ab9c0b32892e2214f
# 4   837bc38c-555e-11e7-9482-93e059bc68e2  5afe5f4ad2b85a2872d5ef1e
# 5   837bc38c-555e-11e7-9482-93e059bc68e2  5ad13e87511dd128fbf037d6
# 6   83923900-555e-11e7-9490-375a9082275e  57f7038f4548b5a70594d0d8
# 7   837bc38c-555e-11e7-9482-93e059bc68e2  5af5815a3c773f289f110187
# 8   837bc38c-555e-11e7-9482-93e059bc68e2  5b08d2eea813c3280f5b9e5a
# 9   83a8e704-555e-11e7-949e-8fcc1a16ded8  5af6b5a6aea83f289269e85b
# 10  837bc38c-555e-11e7-9482-93e059bc68e2  5ad13e87511dd128fbf037d6
# 11  837bc38c-555e-11e7-9482-93e059bc68e2  5af5815a3c773f289f110187
# 12  83923900-555e-11e7-9490-375a9082275e  5af6b5a6aea83f289269e85b
# 13  837bc38c-555e-11e7-9482-93e059bc68e2  57f7038f4548b5a70594d0d8
# 14  837bc38c-555e-11e7-9482-93e059bc68e2  5af6b5a6aea83f289269e85b
# 15  83923900-555e-11e7-9490-375a9082275e  5af7db315d60bf2890e87934
# 16  837bc38c-555e-11e7-9482-93e059bc68e2  5b08d2eea813c3280f5b9e5a
# 17  837bc38c-555e-11e7-9482-93e059bc68e2  5af6b5a6aea83f289269e85b
# 18  83bcbb58-555e-11e7-94aa-f3fb638c302d  59fdc1753acc1e05e9be13f9
# 19  837bc38c-555e-11e7-9482-93e059bc68e2  5b08d2eea813c3280f5b9e5a
#
#          event_key  event_time  drag_start  drag_end  time_stamp  \
# 0       startVideo  2147483647         NaN       NaN         0.0
# 1       startVideo  2147483647         NaN       NaN         0.0
# 2       startVideo  2147483647         NaN       NaN        77.0
# 3        dragVideo  2147483647       166.0     195.0         NaN
# 4       startVideo  2147483647         NaN       NaN         0.0
# 5       startVideo  2147483647         NaN       NaN         0.0
# 6       startVideo  2147483647         NaN       NaN         0.0
# 7        dragVideo  2147483647         0.0      29.0         NaN
# 8        dragVideo  2147483647       289.0     297.0         NaN
# 9       startVideo  2147483647         NaN       NaN         0.0
# 10     finishVideo  2147483647         NaN       NaN         NaN
# 11  clickVideoExit  2147483647         NaN       NaN        32.0
# 12     finishVideo  2147483647         NaN       NaN         NaN
# 13     finishVideo  2147483647         NaN       NaN         NaN
# 14      startVideo  2147483647         NaN       NaN         0.0
# 15      startVideo  2147483647         NaN       NaN         0.0
# 16       dragVideo  2147483647        74.0     136.0         NaN
# 17     finishVideo  2147483647         NaN       NaN         NaN
# 18      startVideo  2147483647         NaN       NaN         0.0
# 19      startVideo  2147483647         NaN       NaN         0.0
#
#     answer_correct
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 7              NaN
# 8              NaN
# 9              NaN
# 10             NaN
# 11             NaN
# 12             NaN
# 13             NaN
# 14             NaN
# 15             NaN
# 16             NaN
# 17             NaN
# 18             NaN
# 19             NaN

# %%
sorted_data = np.array(sorted_data)
length = sorted_data.shape[0]
print(length)
print(sorted_data[:10, :])
# Out:
# 387959
# [['83bcbb58-555e-11e7-94aa-f3fb638c302d' '587b631a62de3357b0b22d33'
#   'startVideo' 2147483647 nan nan 0.0 nan]
#  ['83a8e704-555e-11e7-949e-8fcc1a16ded8' '5af6b5a6aea83f289269e85b'
#   'startVideo' 2147483647 nan nan 0.0 nan]
#  ['83bcbb58-555e-11e7-94aa-f3fb638c302d' '594061454d95b66e2537f50e'
#   'startVideo' 2147483647 nan nan 77.0 nan]
#  ['83bcbb58-555e-11e7-94aa-f3fb638c302d' '5aa7cb7ab9c0b32892e2214f'
#   'dragVideo' 2147483647 166.0 195.0 nan nan]
#  ['837bc38c-555e-11e7-9482-93e059bc68e2' '5afe5f4ad2b85a2872d5ef1e'
#   'startVideo' 2147483647 nan nan 0.0 nan]
#  ['837bc38c-555e-11e7-9482-93e059bc68e2' '5ad13e87511dd128fbf037d6'
#   'startVideo' 2147483647 nan nan 0.0 nan]
#  ['83923900-555e-11e7-9490-375a9082275e' '57f7038f4548b5a70594d0d8'
#   'startVideo' 2147483647 nan nan 0.0 nan]
#  ['837bc38c-555e-11e7-9482-93e059bc68e2' '5af5815a3c773f289f110187'
#   'dragVideo' 2147483647 0.0 29.0 nan nan]
#  ['837bc38c-555e-11e7-9482-93e059bc68e2' '5b08d2eea813c3280f5b9e5a'
#   'dragVideo' 2147483647 289.0 297.0 nan nan]
#  ['83a8e704-555e-11e7-949e-8fcc1a16ded8' '5af6b5a6aea83f289269e85b'
#   'startVideo' 2147483647 nan nan 0.0 nan]]

# %%
extracted_data = []

for i in range(length):
    single_record = sorted_data[i,:]
    exist = False
    for ex_data in extracted_data:
        if ex_data['video_id'] == single_record[0] and ex_data['user_id'] == single_record[1]:
            if single_record[2] == 'startVideo':
                new_opr = {}
                new_opr['start_video'] = single_record[6]
                new_opr['forward'] = []
                new_opr['backward'] = []
                ex_data['operation'].append(new_opr)
            if single_record[2] == 'dragVideo':
                if single_record[4] < single_record[5]:
                    ex_data['operation'][-1]['forward'].append([single_record[4], single_record[5]])
                else:
                    ex_data['operation'][-1]['backward'].append([single_record[4], single_record[5]])
            if single_record[2] == 'finishVideo':
                ex_data['operation'][-1]['finish_video'] = single_record[6]
            if single_record[2] == 'clickVideoExit':
                ex_data['operation'][-1]['exit_video'] = single_record[6]
#            if single_record[2] == 'clickProblemSubmit':
#                ex_data['operation'][-1]['answer_question'] = single_record[7]
            exist = True
            break
    if exist == False and single_record[2] == 'startVideo':
        new_record = {}
        new_record['video_id'] = single_record[0]
        new_record['user_id'] = single_record[1]
        new_record['operation'] = []
        new_opr = {}
        new_opr['start_video'] = []
        new_opr['forward'] = []
        new_opr['backward'] = []
        new_opr['start_video'] = single_record[6]
        new_record['operation'].append(new_opr)
#        if single_record[2] == 'clickProblemSubmit':
#            new_opr['answer_question'] = single_record[7]
#            new_record['operation'].append(new_opr)
        extracted_data.append(new_record)
    if i%10000 == 0:
        print(i)
# print(extracted_data)
# Out:
# 0
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 230000
# 240000
# 250000
# 260000
# 270000
# 280000
# 290000
# 300000
# 310000
# 320000
# 330000
# 340000
# 350000
# 360000
# 370000
# 380000

# %%
print(extracted_data[9])
# Out:
# {'video_id': '837bc38c-555e-11e7-9482-93e059bc68e2', 'user_id': '5b08d2eea813c3280f5b9e5a', 'operation': [{'start_video': 0.0, 'forward': [[255.0, 297.0]], 'backward': []}, {'start_video': 2.0, 'forward': [], 'backward': []}, {'start_video': 0.0, 'forward': [[0.0, 253.0], [6.0, 72.0], [137.0, 287.0]], 'backward': [], 'finish_video': nan}, {'start_video': 1.0, 'forward': [], 'backward': [], 'exit_video': 3.0}, {'start_video': 0.0, 'forward': [], 'backward': [], 'finish_video': nan}, {'start_video': 1.0, 'forward': [], 'backward': []}, {'start_video': 1.0, 'forward': [], 'backward': [], 'exit_video': 2.0}]}

# %%
client = pymongo.MongoClient(host='localhost', port=27017)
db = client['videology_bbjy']
collection = db.videology_bbjy
final = collection.insert_many(extracted_data)

# %%
'''client = pymongo.MongoClient(host='localhost', port=27017)
db = client['first_try']
collection = db.students
student1 = {
    'id': '20170101',
    'name': 'Jordan',
    'age': 20,
    'gender': {'right': [['male','female'],['a','b']],
               'left': [[1,3],[2,3]]}
}
 
student2 = {
    'id': '20170202',
    'name': 'Mike',
    'age': 21,
    'gender': 'male'
}
result = collection.insert_many([student1, student2])'''
